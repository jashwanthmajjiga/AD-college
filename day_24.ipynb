# %% [markdown]
# <a href="https://colab.research.google.com/github/jashwanthmajjiga/AD-college/blob/main/day_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars = pd.read_csv('/content/Cars.csv')
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.sample()
# Out:
#      HP        MPG  VOL          SP         WT
# 72  162  23.203569  132  133.140074  43.353123

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.drop("HP",axis=1).corr()
# Out:
#           MPG       VOL        SP        WT
# MPG  1.000000 -0.529057 -0.687125 -0.526759
# VOL -0.529057  1.000000  0.102170  0.999203
# SP  -0.687125  0.102170  1.000000  0.102439
# WT  -0.526759  0.999203  0.102439  1.000000

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'cars' is your DataFrame and 'MPG' is the column you want to plot
sns.distplot(cars['MPG'])  # Create the distplot
plt.show()  # Display the plot

sns.boxplot(x=cars['MPG']) #Create the boxplot
plt.show() # Display the plot

# Check for the correct column name in your DataFrame using cars.columns
print(cars.columns)  # This will print all the column names in your DataFrame

# Replace 'Cylinders' with the actual column name if it's different
# For example, if the column is named 'cylinders', use:
sns.scatterplot(x='cylinders', y='MPG', data=cars)  # Create a scatter plot

# Or, if the column is named 'Cyl', use:
# sns.scatterplot(x='Cyl', y='MPG', data=cars)  # Create a scatter plot

plt.show() # Display the plot
# Out:
# <ipython-input-19-5cbbcc553ca1>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['MPG'])  # Create the distplot
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-5cbbcc553ca1> in <cell line: 0>()
#      14 # Replace 'Cylinders' with the actual column name if it's different
#      15 # For example, if the column is named 'cylinders', use:
# ---> 16 sns.scatterplot(x='cylinders', y='MPG', data=cars)  # Create a scatter plot
#      17
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from seaborn import displot

# %%
sns.distplot(x=cars['SP'])
plt.show()

# %%
sns.distplot(x=cars['WT'])
plt.title('Distribution of Weight of vechiles in thousand pounds')
plt.xlabel('Weight in Thousand pounds')
plt.show()

# %%
sns.boxplot(x=cars['HP'])
plt.title('Distribution of horse power')
plt.xlabel('hp')
plt.show()

# %%
from seaborn import scatterplot
scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
scatterplot(x=cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>
